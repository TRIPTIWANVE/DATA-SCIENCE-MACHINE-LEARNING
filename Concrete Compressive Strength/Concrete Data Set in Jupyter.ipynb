# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
# from sklearn import svm
# from sklearn.datasets.samples_generator import make_blobs
# X,y=make_blobs(n_samples=40,centers=2,random_state=20)
# clf=svm.SVC(kernel='linear',C=1)
# clf.fit(X,y)

# %%
df=pd.read_csv("F:/DATA SCIENCE PROJECT/ALL/DATASET/Concrete_Data.csv")

# %%
from sklearn.metrics import r2_score
print(df.isnull().sum())
# Out:
# Cement              0
# Blast               0
# Fly Ash             0
# Water               0
# Superplasticizer    0
# CA                  0
# FA                  0
# Age                 0
# CMS                 0
# dtype: int64

# %%
df.columns=['cement','blast','flyash','water','superplasticiser','coarse','fine','age','ccs']
col=list(df.columns)
print(col)
# Out:
# ['cement', 'blast', 'flyash', 'water', 'superplasticiser', 'coarse', 'fine', 'age', 'ccs']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
#X = df.drop(['ccs'],axis =1)
X=df.iloc[:,[1,5,8]].values
Y = df['ccs']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3,random_state=101)
corr = df.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
pred = model.predict(X_test)

from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(Y_test,pred))
print('rmse:',rmse)

print('Abs model coefficent',abs(model.coef_))
print('B0',model.intercept_)
print('R-squared error Regression model',r2_score(Y_test, pred))
# Out:
# rmse: 1.560858159378079e-14
# Abs model coefficent [3.74562028e-17 1.38777878e-17 1.00000000e+00]
# B0 7.105427357601002e-15
# R-squared error Regression model 1.0
